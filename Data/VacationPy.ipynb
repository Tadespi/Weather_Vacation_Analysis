# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                        sitka  57.0531 -135.3300     42.89
# 1        1                        ginir   7.1333   40.7000     55.65
# 2        2                    grytviken -54.2811  -36.5092     36.93
# 3        3  edinburgh of the seven seas -37.0676  -12.3116     56.89
# 4        4                  port alfred -33.5906   26.8910     57.74
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        90         100        4.16      US  1698721267
# 1        85          17        3.02      ET  1698721375
# 2        82          88        6.67      GS  1698721376
# 3        95         100       27.65      SH  1698721376
# 4        80          21       15.21      ZA  1698721376

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points("Lng", "Lat", geo = True,tiles = "OSM",
                                        frame_width = 700, frame_height = 700, size = "Humidity", color="City")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
fit_city = city_data_df[(city_data_df["Max Temp"] >=20) & (city_data_df["Humidity"] >=50) & (city_data_df["Cloudiness"]==0)]
# Drop any rows with null values
new_city_df= fit_city.dropna()

# Display sample data
new_city_df
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 15        15                     santana  -0.0583  -51.1817     82.58
# 29        29                     dobrich  43.5667   27.8333     53.69
# 40        40                  bredasdorp -34.5322   20.0403     55.69
# 53        53                        argo  37.6333   22.7333     64.56
# 66        66               prince rupert  54.3161 -130.3201     44.29
# 78        78                     ofunato  39.0717  141.7167     64.18
# 80        80                   tazacorte  28.6290  -17.9293     72.57
# 94        94                punta arenas -53.1500  -70.9167     37.51
# 106      106                     bizerte  37.2744    9.8739     71.60
# 118      118                  mossel bay -34.1831   22.1460     48.13
# 119      119                kristiansund  63.1115    7.7320     27.25
# 135      135                    jinxiang  27.4327  120.6062     72.73
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = new_city_df.copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
# Display sample data
hotel_df.drop (["City_ID", "Max Temp", "Cloudiness", "Wind Speed", "Date"], axis =1)
# Out:
#                            City      Lat       Lng  Humidity Country  \
# 15                      santana  -0.0583  -51.1817        74      BR
# 29                      dobrich  43.5667   27.8333        79      BG
# 40                   bredasdorp -34.5322   20.0403        80      ZA
# 53                         argo  37.6333   22.7333        73      GR
# 66                prince rupert  54.3161 -130.3201        81      CA
# 78                      ofunato  39.0717  141.7167        58      JP
# 80                    tazacorte  28.6290  -17.9293        91      ES
# 94                 punta arenas -53.1500  -70.9167        60      CL
# 106                     bizerte  37.2744    9.8739        83      TN
# 118                  mossel bay -34.1831   22.1460        76      ZA
# 119                kristiansund  63.1115    7.7320        80      NO
# 135                    jinxiang  27.4327  120.6062        67      CN
# 155                      namibe -15.1961   12.1522        79      AO
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
limit = 30
params = {"type":"hotel",
         "keyword":"hotel","radius":10000,
          "api_keys": geoapify_key}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat}, {radius}"
    params["bias"] = f"proximity:{lon}, {lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address_json = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address_json["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# santana - nearest hotel: No hotel found
# dobrich - nearest hotel: No hotel found
# bredasdorp - nearest hotel: No hotel found
# argo - nearest hotel: No hotel found
# prince rupert - nearest hotel: No hotel found
# ofunato - nearest hotel: No hotel found
# tazacorte - nearest hotel: No hotel found
# punta arenas - nearest hotel: No hotel found
# bizerte - nearest hotel: No hotel found
# mossel bay - nearest hotel: No hotel found
# kristiansund - nearest hotel: No hotel found
# jinxiang - nearest hotel: No hotel found
# namibe - nearest hotel: No hotel found
# beatrice - nearest hotel: No hotel found
# kapuskasing - nearest hotel: No hotel found
# lompoc - nearest hotel: No hotel found
# mar del plata - nearest hotel: No hotel found
# corinto - nearest hotel: No hotel found
# santander - nearest hotel: No hotel found
# vila velha - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: No hotel found
# laguna - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points("Lng", "Lat",geo=True, tiles = "OSM", frame_width = 700, frame_height = 700,
                                   color="City", hover_cols= ['Lng', 'Lat', 'City', 'Humidity', 'Hotel Name', 
                                                                'Country'])
# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
